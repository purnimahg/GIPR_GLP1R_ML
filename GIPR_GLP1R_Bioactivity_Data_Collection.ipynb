# %% [markdown]
# <a href="https://colab.research.google.com/github/purnimahg/GIPR_GLP1R_ML/blob/main/GIPR_GLP1R_Bioactivity_Data_Collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 7.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('GLP1')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references           organism  \
# 0               []       Homo sapiens
# 1               []  Rattus norvegicus
# 2               []       Mus musculus
# 3               []       Homo sapiens
# 4               []       Homo sapiens
# 5               []       Homo sapiens
#
#                                            pref_name  score  \
# 0                   Glucagon-like peptide 1 receptor   13.0
# 1                   Glucagon-like peptide 1 receptor   13.0
# 2                   Glucagon-like peptide 1 receptor   13.0
# 3  Histone-lysine N-methyltransferase, H3 lysine-...   11.0
# 4                                           Glucagon    9.0
# 5     Histone-lysine N-methyltransferase EHMT1/EHMT2    7.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL1784
# 1               False       CHEMBL5862
# 2               False    CHEMBL1075290
# 3               False       CHEMBL6031
# 4               False       CHEMBL5736
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Glucagon-like peptide 1 receptor* (first entry)**

# %% [markdown]
# We will assign the first entry (which corresponds to the target signle protein, *Glucagon-like peptide 1 receptor*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL1784'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Glucagon-like peptide 1 receptor* (CHEMBL1784) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 344                                               None             None
# 345                                               None             None
# 346                                               None             None
# 347  {'action_type': 'ANTAGONIST', 'description': '...             None
# 348  {'action_type': 'ANTAGONIST', 'description': '...             None
#
#      activity_id activity_properties assay_chembl_id  \
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('glp1r_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# Mounting Google drive to Colab for easy access

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %%
! cp glp1r_bioactivity_data_raw.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 306
# -rw------- 1 root root 312577 Feb  4 15:51 glp1r_bioactivity_data_raw.csv

# %%
# !ls
# Out:
# gdrive	glp1r_bioactivity_data_raw.csv	sample_data

# %%
! head glp1r_bioactivity_data_raw.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-18-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 344                                               None             None
# 345                                               None             None
# 346                                               None             None
# 347  {'action_type': 'ANTAGONIST', 'description': '...             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 254

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# 5                                                 None             None
# ..                                                 ...              ...
# 344                                               None             None
# 345                                               None             None
# 346                                               None             None
# 347  {'action_type': 'ANTAGONIST', 'description': '...             None
# 348  {'action_type': 'ANTAGONIST', 'description': '...             None
#
#      activity_id activity_properties assay_chembl_id  \
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL410972  CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# 2         CHEMBL265428  CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# 3         CHEMBL439104  CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# 4         CHEMBL409873  CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# 5         CHEMBL410973  CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# ..                 ...                                                ...
# 344       CHEMBL540612    COc1ccccc1N1CCN(CCCCNC(=O)c2ccc3ccccc3c2)CC1.Cl
# 345      CHEMBL2164551             N#Cc1cc(F)cc(-c2nc(-c3ccc(F)cn3)no2)c1
# 346      CHEMBL2018969  COc1cccc2c1c(NS(=O)(=O)c1ccc(Cl)s1)nn2Cc1cccc(...
# 347      CHEMBL5075931  NCCc1cn(S(=O)(=O)c2c(Cl)nc3sccn23)c2ccccc12.O=...
# 348      CHEMBL5089005  COc1ccc(NC(=O)c2ccc(-c3ccc(-c4noc(C)n4)cc3C)cc...
#
#     standard_value
# 0             14.0
# 2           5354.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('glp1r_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('glp1r_02_bioactivity_data_preprocessed.csv')

# %%
! ls -l
# Out:
# total 508
# -rw-r--r-- 1 root root  96179 Feb  4 15:58 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# drwx------ 6 root root   4096 Feb  4 15:51 gdrive
# -rw-r--r-- 1 root root  96179 Feb  4 15:59 glp1r_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root 312577 Feb  4 15:51 glp1r_bioactivity_data_raw.csv
# drwxr-xr-x 1 root root   4096 Jan 31 14:18 sample_data

# %%
! cp glp1r_02_bioactivity_data_preprocessed.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
df4.molecule_chembl_id
# Out:
# 0       CHEMBL410972
# 1       CHEMBL265428
# 2       CHEMBL439104
# 3       CHEMBL409873
# 4       CHEMBL410973
#            ...
# 249     CHEMBL540612
# 250    CHEMBL2164551
# 251    CHEMBL2018969
# 252    CHEMBL5075931
# 253    CHEMBL5089005
# Name: molecule_chembl_id, Length: 254, dtype: object

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL410972  CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# 1         CHEMBL265428  CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# 2         CHEMBL439104  CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# 3         CHEMBL409873  CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# 4         CHEMBL410973  CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# ..                 ...                                                ...
# 249       CHEMBL540612    COc1ccccc1N1CCN(CCCCNC(=O)c2ccc3ccccc3c2)CC1.Cl
# 250      CHEMBL2164551             N#Cc1cc(F)cc(-c2nc(-c3ccc(F)cn3)no2)c1
# 251      CHEMBL2018969  COc1cccc2c1c(NS(=O)(=O)c1ccc(Cl)s1)nn2Cc1cccc(...
# 252      CHEMBL5075931  NCCc1cn(S(=O)(=O)c2c(Cl)nc3sccn23)c2ccccc12.O=...
# 253      CHEMBL5089005  COc1ccc(NC(=O)c2ccc(-c3ccc(-c4noc(C)n4)cc3C)cc...
#
#      standard_value         class
# 0             14.00        active
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('glp1r_03_bioactivity_data_curated.csv', index=False)

# %%
! cp glp1r_03_bioactivity_data_curated.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! zip gipr_glp1r.zip *.csv
# Out:
# updating: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 94%)
# updating: glp1r_02_bioactivity_data_preprocessed.csv (deflated 94%)
# updating: glp1r_03_bioactivity_data_curated.csv (deflated 94%)
# updating: glp1r_bioactivity_data_raw.csv (deflated 95%)

# %%
! ls -l
# Out:
# total 644
# -rw-r--r-- 1 root root  96179 Feb  4 15:58 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# drwx------ 6 root root   4096 Feb  4 15:51 gdrive
# -rw-r--r-- 1 root root  34355 Feb  4 16:22 gipr_glp1r.zip
# -rw-r--r-- 1 root root  96179 Feb  4 15:59 glp1r_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  98383 Feb  4 16:19 glp1r_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root 312577 Feb  4 15:51 glp1r_bioactivity_data_raw.csv
# drwxr-xr-x 1 root root   4096 Jan 31 14:18 sample_data

# %%
! cp gipr_glp1r.zip "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l
# Out:
# total 644
# -rw-r--r-- 1 root root  96179 Feb  4 15:58 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# drwx------ 6 root root   4096 Feb  4 15:51 gdrive
# -rw-r--r-- 1 root root  34355 Feb  4 16:22 gipr_glp1r.zip
# -rw-r--r-- 1 root root  96179 Feb  4 15:59 glp1r_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  98383 Feb  4 16:19 glp1r_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root 312577 Feb  4 15:51 glp1r_bioactivity_data_raw.csv
# drwxr-xr-x 1 root root   4096 Jan 31 14:18 sample_data

# %% [markdown]
# ---
